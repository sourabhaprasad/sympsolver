# %%
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

# %%
PINECONE_API_KEY = "pcsk_6vak7A_QZQEv68cSuCxJjXkuFDQ1Y9q9Dt4rFJ5nsXwr8Hm1BTBsKQU541hnCqSj5o3GiT"
PINECONE_API_ENV = "us-east-1-aws"
INDEX_NAME = "medicalbot"

# %%
from pinecone import Pinecone
pc = Pinecone(api_key=PINECONE_API_KEY)

# %%
index = pc.Index("medicalbot")

# %%
def load_pdf(data):
    loader = DirectoryLoader(
        data,
        glob="*.pdf",
        loader_cls=PyPDFLoader
    )
    documents = loader.load()
    return documents

# %%
extracted_data = load_pdf("../data")
print(f"Loaded {len(extracted_data)} documents from PDF files.")
# Out:
# Loaded 637 documents from PDF files.

# %%
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=200,
        chunk_overlap=20
    )
    text_chunks = text_splitter.split_documents(extracted_data)
    return text_chunks

# %%
text_chunks = text_split(extracted_data)
print("Length of text chunks:", len(text_chunks))
# Out:
# Length of text chunks: 15616

# %%
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    return embeddings

embeddings = download_hugging_face_embeddings()

# %%
# docsearch=Pinecone.from_texts([t.page_content for t in text_chunks], embeddings, index_name=index_name)

# %%
def store_embeddings_in_batches(index, text_chunks, embeddings, batch_size=100):
    """
    Store embeddings in Pinecone in smaller batches to avoid exceeding size limits.
    """
    print("Storing embeddings in batches...")
    for i in range(0, len(text_chunks), batch_size):
        batch = text_chunks[i:i + batch_size]
        vectors = [
            (f"chunk-{i+j}", embeddings.embed_documents([chunk.page_content])[0], {"text": chunk.page_content})
            for j, chunk in enumerate(batch)
        ]
        try:
            index.upsert(vectors)
            print(f"Stored batch {i // batch_size + 1} with {len(vectors)} embeddings.")
        except Exception as e:
            print(f"Error storing batch {i // batch_size + 1}: {e}")

# %%
store_embeddings_in_batches(index, text_chunks, embeddings, batch_size=50)
# Out:
# Storing embeddings in batches...
# Stored batch 1 with 50 embeddings.
# Stored batch 2 with 50 embeddings.
# Stored batch 3 with 50 embeddings.
# Stored batch 4 with 50 embeddings.
# Stored batch 5 with 50 embeddings.
# Stored batch 6 with 50 embeddings.
# Stored batch 7 with 50 embeddings.
# Stored batch 8 with 50 embeddings.
# Stored batch 9 with 50 embeddings.
# Stored batch 10 with 50 embeddings.
# Stored batch 11 with 50 embeddings.
# Stored batch 12 with 50 embeddings.
# Stored batch 13 with 50 embeddings.
# Stored batch 14 with 50 embeddings.
# Stored batch 15 with 50 embeddings.
# Stored batch 16 with 50 embeddings.
# Stored batch 17 with 50 embeddings.
# Stored batch 18 with 50 embeddings.
# Stored batch 19 with 50 embeddings.
# Stored batch 20 with 50 embeddings.
# Stored batch 21 with 50 embeddings.
# Stored batch 22 with 50 embeddings.
# Stored batch 23 with 50 embeddings.
# Stored batch 24 with 50 embeddings.
# Stored batch 25 with 50 embeddings.
# Stored batch 26 with 50 embeddings.
# Stored batch 27 with 50 embeddings.
# Stored batch 28 with 50 embeddings.
# Stored batch 29 with 50 embeddings.
# Stored batch 30 with 50 embeddings.
# Stored batch 31 with 50 embeddings.
# Stored batch 32 with 50 embeddings.
# Stored batch 33 with 50 embeddings.
# Stored batch 34 with 50 embeddings.
# Stored batch 35 with 50 embeddings.
# Stored batch 36 with 50 embeddings.
# Stored batch 37 with 50 embeddings.
# Stored batch 38 with 50 embeddings.
# Stored batch 39 with 50 embeddings.
# Stored batch 40 with 50 embeddings.
# Stored batch 41 with 50 embeddings.
# Stored batch 42 with 50 embeddings.
# Stored batch 43 with 50 embeddings.
# Stored batch 44 with 50 embeddings.
# Stored batch 45 with 50 embeddings.
# Stored batch 46 with 50 embeddings.
# Stored batch 47 with 50 embeddings.
# Stored batch 48 with 50 embeddings.
# Stored batch 49 with 50 embeddings.
# Stored batch 50 with 50 embeddings.
# Stored batch 51 with 50 embeddings.
# Stored batch 52 with 50 embeddings.
# Stored batch 53 with 50 embeddings.
# Stored batch 54 with 50 embeddings.
# Stored batch 55 with 50 embeddings.
# Stored batch 56 with 50 embeddings.
# Stored batch 57 with 50 embeddings.
# Stored batch 58 with 50 embeddings.
# Stored batch 59 with 50 embeddings.
# Stored batch 60 with 50 embeddings.
# Stored batch 61 with 50 embeddings.
# Stored batch 62 with 50 embeddings.
# Stored batch 63 with 50 embeddings.
# Stored batch 64 with 50 embeddings.
# Stored batch 65 with 50 embeddings.
# Stored batch 66 with 50 embeddings.
# Stored batch 67 with 50 embeddings.
# Stored batch 68 with 50 embeddings.
# Stored batch 69 with 50 embeddings.
# Stored batch 70 with 50 embeddings.
# Stored batch 71 with 50 embeddings.
# Stored batch 72 with 50 embeddings.
# Stored batch 73 with 50 embeddings.
# Stored batch 74 with 50 embeddings.
# Stored batch 75 with 50 embeddings.
# Stored batch 76 with 50 embeddings.
# Stored batch 77 with 50 embeddings.
# Stored batch 78 with 50 embeddings.
# Stored batch 79 with 50 embeddings.
# Stored batch 80 with 50 embeddings.
# Stored batch 81 with 50 embeddings.
# Stored batch 82 with 50 embeddings.
# Stored batch 83 with 50 embeddings.
# Stored batch 84 with 50 embeddings.
# Stored batch 85 with 50 embeddings.
# Stored batch 86 with 50 embeddings.
# Stored batch 87 with 50 embeddings.
# Stored batch 88 with 50 embeddings.
# Stored batch 89 with 50 embeddings.
# Stored batch 90 with 50 embeddings.
# Stored batch 91 with 50 embeddings.
# Stored batch 92 with 50 embeddings.
# Stored batch 93 with 50 embeddings.
# Stored batch 94 with 50 embeddings.
# Stored batch 95 with 50 embeddings.
# Stored batch 96 with 50 embeddings.
# Stored batch 97 with 50 embeddings.
# Stored batch 98 with 50 embeddings.
# Stored batch 99 with 50 embeddings.
# Stored batch 100 with 50 embeddings.
# Stored batch 101 with 50 embeddings.
# Stored batch 102 with 50 embeddings.
# Stored batch 103 with 50 embeddings.
# Stored batch 104 with 50 embeddings.
# Stored batch 105 with 50 embeddings.
# Stored batch 106 with 50 embeddings.
# Stored batch 107 with 50 embeddings.
# Stored batch 108 with 50 embeddings.
# Stored batch 109 with 50 embeddings.
# Stored batch 110 with 50 embeddings.
# Stored batch 111 with 50 embeddings.
# Stored batch 112 with 50 embeddings.
# Stored batch 113 with 50 embeddings.
# Stored batch 114 with 50 embeddings.
# Stored batch 115 with 50 embeddings.
# Stored batch 116 with 50 embeddings.
# Stored batch 117 with 50 embeddings.
# Stored batch 118 with 50 embeddings.
# Stored batch 119 with 50 embeddings.
# Stored batch 120 with 50 embeddings.
# Stored batch 121 with 50 embeddings.
# Stored batch 122 with 50 embeddings.
# Stored batch 123 with 50 embeddings.
# Stored batch 124 with 50 embeddings.
# Stored batch 125 with 50 embeddings.
# Stored batch 126 with 50 embeddings.
# Stored batch 127 with 50 embeddings.
# Stored batch 128 with 50 embeddings.
# Stored batch 129 with 50 embeddings.
# Stored batch 130 with 50 embeddings.
# Stored batch 131 with 50 embeddings.
# Stored batch 132 with 50 embeddings.
# Stored batch 133 with 50 embeddings.
# Stored batch 134 with 50 embeddings.
# Stored batch 135 with 50 embeddings.
# Stored batch 136 with 50 embeddings.
# Stored batch 137 with 50 embeddings.
# Stored batch 138 with 50 embeddings.
# Stored batch 139 with 50 embeddings.
# Stored batch 140 with 50 embeddings.
# Stored batch 141 with 50 embeddings.
# Stored batch 142 with 50 embeddings.
# Stored batch 143 with 50 embeddings.
# Stored batch 144 with 50 embeddings.
# Stored batch 145 with 50 embeddings.
# Stored batch 146 with 50 embeddings.
# Stored batch 147 with 50 embeddings.
# Stored batch 148 with 50 embeddings.
# Stored batch 149 with 50 embeddings.
# Stored batch 150 with 50 embeddings.
# Stored batch 151 with 50 embeddings.
# Stored batch 152 with 50 embeddings.
# Stored batch 153 with 50 embeddings.
# Stored batch 154 with 50 embeddings.
# Stored batch 155 with 50 embeddings.
# Stored batch 156 with 50 embeddings.
# Stored batch 157 with 50 embeddings.
# Stored batch 158 with 50 embeddings.
# Stored batch 159 with 50 embeddings.
# Stored batch 160 with 50 embeddings.
# Stored batch 161 with 50 embeddings.
# Stored batch 162 with 50 embeddings.
# Stored batch 163 with 50 embeddings.
# Stored batch 164 with 50 embeddings.
# Stored batch 165 with 50 embeddings.
# Stored batch 166 with 50 embeddings.
# Stored batch 167 with 50 embeddings.
# Stored batch 168 with 50 embeddings.
# Stored batch 169 with 50 embeddings.
# Stored batch 170 with 50 embeddings.
# Stored batch 171 with 50 embeddings.
# Stored batch 172 with 50 embeddings.
# Stored batch 173 with 50 embeddings.
# Stored batch 174 with 50 embeddings.
# Stored batch 175 with 50 embeddings.
# Stored batch 176 with 50 embeddings.
# Stored batch 177 with 50 embeddings.
# Stored batch 178 with 50 embeddings.
# Stored batch 179 with 50 embeddings.
# Stored batch 180 with 50 embeddings.
# Stored batch 181 with 50 embeddings.
# Stored batch 182 with 50 embeddings.
# Stored batch 183 with 50 embeddings.
# Stored batch 184 with 50 embeddings.
# Stored batch 185 with 50 embeddings.
# Stored batch 186 with 50 embeddings.
# Stored batch 187 with 50 embeddings.
# Stored batch 188 with 50 embeddings.
# Stored batch 189 with 50 embeddings.
# Stored batch 190 with 50 embeddings.
# Stored batch 191 with 50 embeddings.
# Stored batch 192 with 50 embeddings.
# Stored batch 193 with 50 embeddings.
# Stored batch 194 with 50 embeddings.
# Stored batch 195 with 50 embeddings.
# Stored batch 196 with 50 embeddings.
# Stored batch 197 with 50 embeddings.
# Stored batch 198 with 50 embeddings.
# Stored batch 199 with 50 embeddings.
# Stored batch 200 with 50 embeddings.
# Stored batch 201 with 50 embeddings.
# Stored batch 202 with 50 embeddings.
# Stored batch 203 with 50 embeddings.
# Stored batch 204 with 50 embeddings.
# Stored batch 205 with 50 embeddings.
# Stored batch 206 with 50 embeddings.
# Stored batch 207 with 50 embeddings.
# Stored batch 208 with 50 embeddings.
# Stored batch 209 with 50 embeddings.
# Stored batch 210 with 50 embeddings.
# Stored batch 211 with 50 embeddings.
# Stored batch 212 with 50 embeddings.
# Stored batch 213 with 50 embeddings.
# Stored batch 214 with 50 embeddings.
# Stored batch 215 with 50 embeddings.
# Stored batch 216 with 50 embeddings.
# Stored batch 217 with 50 embeddings.
# Stored batch 218 with 50 embeddings.
# Stored batch 219 with 50 embeddings.
# Stored batch 220 with 50 embeddings.
# Stored batch 221 with 50 embeddings.
# Stored batch 222 with 50 embeddings.
# Stored batch 223 with 50 embeddings.
# Stored batch 224 with 50 embeddings.
# Stored batch 225 with 50 embeddings.
# Stored batch 226 with 50 embeddings.
# Stored batch 227 with 50 embeddings.
# Stored batch 228 with 50 embeddings.
# Stored batch 229 with 50 embeddings.
# Stored batch 230 with 50 embeddings.
# Stored batch 231 with 50 embeddings.
# Stored batch 232 with 50 embeddings.
# Stored batch 233 with 50 embeddings.
# Stored batch 234 with 50 embeddings.
# Stored batch 235 with 50 embeddings.
# Stored batch 236 with 50 embeddings.
# Stored batch 237 with 50 embeddings.
# Stored batch 238 with 50 embeddings.
# Stored batch 239 with 50 embeddings.
# Stored batch 240 with 50 embeddings.
# Stored batch 241 with 50 embeddings.
# Stored batch 242 with 50 embeddings.
# Stored batch 243 with 50 embeddings.
# Stored batch 244 with 50 embeddings.
# Stored batch 245 with 50 embeddings.
# Stored batch 246 with 50 embeddings.
# Stored batch 247 with 50 embeddings.
# Stored batch 248 with 50 embeddings.
# Stored batch 249 with 50 embeddings.
# Stored batch 250 with 50 embeddings.
# Stored batch 251 with 50 embeddings.
# Stored batch 252 with 50 embeddings.
# Stored batch 253 with 50 embeddings.
# Stored batch 254 with 50 embeddings.
# Stored batch 255 with 50 embeddings.
# Stored batch 256 with 50 embeddings.
# Stored batch 257 with 50 embeddings.
# Stored batch 258 with 50 embeddings.
# Stored batch 259 with 50 embeddings.
# Stored batch 260 with 50 embeddings.
# Stored batch 261 with 50 embeddings.
# Stored batch 262 with 50 embeddings.
# Stored batch 263 with 50 embeddings.
# Stored batch 264 with 50 embeddings.
# Stored batch 265 with 50 embeddings.
# Stored batch 266 with 50 embeddings.
# Stored batch 267 with 50 embeddings.
# Stored batch 268 with 50 embeddings.
# Stored batch 269 with 50 embeddings.
# Stored batch 270 with 50 embeddings.
# Stored batch 271 with 50 embeddings.
# Stored batch 272 with 50 embeddings.
# Stored batch 273 with 50 embeddings.
# Stored batch 274 with 50 embeddings.
# Stored batch 275 with 50 embeddings.
# Stored batch 276 with 50 embeddings.
# Stored batch 277 with 50 embeddings.
# Stored batch 278 with 50 embeddings.
# Stored batch 279 with 50 embeddings.
# Stored batch 280 with 50 embeddings.
# Stored batch 281 with 50 embeddings.
# Stored batch 282 with 50 embeddings.
# Stored batch 283 with 50 embeddings.
# Stored batch 284 with 50 embeddings.
# Stored batch 285 with 50 embeddings.
# Stored batch 286 with 50 embeddings.
# Stored batch 287 with 50 embeddings.
# Stored batch 288 with 50 embeddings.
# Stored batch 289 with 50 embeddings.
# Stored batch 290 with 50 embeddings.
# Stored batch 291 with 50 embeddings.
# Stored batch 292 with 50 embeddings.
# Stored batch 293 with 50 embeddings.
# Stored batch 294 with 50 embeddings.
# Stored batch 295 with 50 embeddings.
# Stored batch 296 with 50 embeddings.
# Stored batch 297 with 50 embeddings.
# Stored batch 298 with 50 embeddings.
# Stored batch 299 with 50 embeddings.
# Stored batch 300 with 50 embeddings.
# Stored batch 301 with 50 embeddings.
# Stored batch 302 with 50 embeddings.
# Stored batch 303 with 50 embeddings.
# Stored batch 304 with 50 embeddings.
# Stored batch 305 with 50 embeddings.
# Stored batch 306 with 50 embeddings.
# Stored batch 307 with 50 embeddings.
# Stored batch 308 with 50 embeddings.
# Stored batch 309 with 50 embeddings.
# Stored batch 310 with 50 embeddings.
# Stored batch 311 with 50 embeddings.
# Stored batch 312 with 50 embeddings.
# Stored batch 313 with 16 embeddings.
